# %%
import numpy as np
import pandas as pd

# Load feature matrix
from dataIO.loader import loadTrainingDataFeatures, createSubSet
from vizTools.hdPlot import visualize2D, visualize3D
iD, X = loadTrainingDataFeatures(isNormalized=True)

# %%
print(iD)
print(iD.size)
print(X)
print(X.shape)
#X = [1_Substrate] + [2_Base or Conjugate] + [3_Hydroxyamine or Oxoammonium] + [4_Anti or Syn Ligand]
#ID:
from sklearn.decomposition import PCA

n_features = X.shape[1]
pca = PCA(n_components=n_features)
pca_result = pca.fit_transform(X)
print(pca.explained_variance_ratio_)
t = 0
for i in range(0,n_features):
    t = t + pca.explained_variance_ratio_[i]
    print(i,". ", t*100)
# Out:
# [['Sub-A_CA-A_Hyd-A_LigS-A']
#  ['Sub-A_CA-A_Hyd-A_LigS-B']
#  ['Sub-A_CA-A_Hyd-A_LigS-C']
#  ...
#  ['Sub-AC_Base-E_Oxo-F_LigA-D']
#  ['Sub-AC_Base-E_Oxo-F_LigA-E']
#  ['Sub-AC_Base-E_Oxo-F_LigA-F']]
# 41760
# [[-7.24498693e-01 -7.55462047e-01 -2.62020539e-01 ...  8.95951640e-01
#   -3.28329459e-01  3.46483461e-01]
#  [-7.24498693e-01 -7.55462047e-01 -2.62020539e-01 ...  1.65038990e+00
#   -2.18564586e+00 -1.81874912e+00]
#  [-7.24498693e-01 -7.55462047e-01 -2.62020539e-01 ...  5.49305691e-01
#   -1.22838386e-03  6.76394299e-01]
#  ...
#  [-1.05197923e+00  1.52116379e+00 -1.11419949e+00 ... -1.87182068e+00
#    3.63075174e-01  5.76187736e-01]
#  [-1.05197923e+00  1.52116379e+00 -1.11419949e+00 ... -1.08770845e+00
#    6.50166031e-01  4.23565433e-01]
#  [-1.05197923e+00  1.52116379e+00 -1.11419949e+00 ...  7.11163721e-01
#    1.28541597e+00  1.19477056e-02]]
# (41760, 32)
# [1.91643642e-01 1.24273835e-01 8.53664139e-02 7.14449065e-02
#  6.61102548e-02 5.80184096e-02 5.14926726e-02 5.13568302e-02
#  5.01483517e-02 4.20009753e-02 3.33500701e-02 2.96291735e-02
#  2.82217404e-02 2.40299728e-02 2.19632685e-02 1.75020193e-02
#  1.26518280e-02 1.05272714e-02 9.68115512e-03 7.71242663e-03
#  5.15921990e-03 2.10692673e-03 1.96390954e-03 1.67376237e-03
#  1.15054211e-03 5.70312068e-04 2.41025941e-04 7.39039097e-06
#  1.69344591e-06 1.91337277e-33 1.91337277e-33 1.91337277e-33]
# 0 .  19.164364196304728
# 1 .  31.591747710779206
# 2 .  40.12838910105181
# 3 .  47.27287974873938
# 4 .  53.8839052271539
# 5 .  59.68574619057253
# 6 .  64.83501345184065
# 7 .  69.9706964744841
# 8 .  74.98553164492962
# 9 .  79.18562917704529
# 10 .  82.52063618860342
# 11 .  85.48355353625726
# 12 .  88.30572758017873
# 13 .  90.70872486347086
# 14 .  92.90505170871249
# 15 .  94.65525364238006
# 16 .  95.92043643831622
# 17 .  96.97316357556231
# 18 .  97.94127908788664
# 19 .  98.71252175093844
# 20 .  99.22844374056395
# 21 .  99.43913641349033
# 22 .  99.63552736758807
# 23 .  99.80290360486076
# 24 .  99.91795781536729
# 25 .  99.97498902217403
# 26 .  99.99909161631228
# 27 .  99.99983065540891
# 28 .  99.99999999999997
# 29 .  99.99999999999997
# 30 .  99.99999999999997
# 31 .  99.99999999999997
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 3000 samples in 0.011s...
# [t-SNE] Computed neighbors for 3000 samples in 0.708s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3000
# [t-SNE] Computed conditional probabilities for sample 2000 / 3000
# [t-SNE] Computed conditional probabilities for sample 3000 / 3000
# [t-SNE] Mean sigma: 1.982930
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 72.243164
# [t-SNE] KL divergence after 300 iterations: 1.297373
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-0db562437482> in <module>
#      21 tsne_result = tsne.fit_transform(X1)
#      22
# ---> 23 print(tsne.explained_variance_ratio_)
#      24 t = 0
#      25 for i in range(0,3):
#
# AttributeError: 'TSNE' object has no attribute 'explained_variance_ratio_'

# %%
visualize2D(X)
visualize3D(X)

# %%
X1, idX1 = createSubSet(X, 3000)
iD1 = iD[idX1]
visualize2D(X1)
visualize3D(X1)

# %%
print(X1.shape)
from sklearn_extra.cluster import KMedoids
kmedoids = KMedoids(n_clusters=2, random_state=0).fit(X1)
print(kmedoids.labels_)
print(kmedoids.cluster_centers_)

visualize2D(X1, kmedoids.labels_)
visualize3D(X1, kmedoids.labels_)
# Out:
# (3000, 32)
# [1 0 0 ... 1 1 1]
# [[-0.06953761 -0.72246747 -0.2924555   0.10836568  0.30809963 -0.7791425
#   -0.21986577  0.11681878 -0.10549028 -0.0034729  -1.16887229 -0.40482677
#   -0.61076569 -0.18414314 -1.14333335 -1.17802268 -0.38081082 -1.47249159
#    0.77625728 -0.75747032 -1.0114818  -0.96356175 -0.82315954  1.05066965
#    1.06109861  0.          0.          0.         -1.05861274 -0.79411596
#    0.17916856 -0.20542345]
#  [-0.06953761 -0.72246747 -0.2924555   0.10836568  0.30809963 -0.7791425
#   -0.21986577  0.11681878 -0.10549028 -0.0034729  -1.16887229 -0.40482677
#    1.17005815 -0.267837    0.77417228  1.04426558  0.37341644  0.62670057
#   -0.09250734  1.15357396  1.00708608  0.97335209  0.98554434 -0.75038782
#   -1.03847505  0.          0.          0.          0.97474576  0.89595164
#   -0.32832946  0.34648346]]

# %%
from sklearn.cluster import KMeans
km = KMeans(2)
clusts = km.fit_predict(X1)
visualize2D(X1, clusts)
visualize3D(X1, clusts)

# %%
# Export clustering results to file
idx = np.arange(0, X1.shape[0], 1)
idx0 = idx[clusts==0]
idx1 = idx[clusts==1]

print(iD[idx0].shape, iD[idx1].shape)
df1 = pd.DataFrame(data = iD1[idx0],columns={'id'})
df1["cluster"] = clusts[idx0]
df2 = pd.DataFrame(data = iD1[idx1],columns={'id'})
df2["cluster"] = clusts[idx1]
df = pd.concat([df1,df2])
df.to_csv('clusters.csv', index=False)
df.head()
# Out:
# (1484, 1) (1516, 1)
#                           id  cluster
# 0    Sub-V_CA-D_Oxo-C_LigS-B        0
# 1    Sub-R_CA-E_Oxo-F_LigS-C        0
# 2  Sub-F_Base-C_Oxo-A_LigA-A        0
# 3  Sub-Z_Base-C_Oxo-E_LigS-A        0
# 4    Sub-K_CA-B_Oxo-E_LigA-B        0

# %%
from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=1, min_samples=3).fit(X1)

visualize2D(X1, dbscan.labels_)
visualize3D(X1, dbscan.labels_)

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import seaborn as sns
import time

X1, idX1 = createSubSet(X, 5000)
iD1 = iD[idX1] 
time_start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
X2 = tsne.fit_transform(X1)
print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 5000 samples in 0.008s...
# [t-SNE] Computed neighbors for 5000 samples in 1.748s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5000
# [t-SNE] Computed conditional probabilities for sample 2000 / 5000
# [t-SNE] Computed conditional probabilities for sample 3000 / 5000
# [t-SNE] Computed conditional probabilities for sample 4000 / 5000
# [t-SNE] Computed conditional probabilities for sample 5000 / 5000
# [t-SNE] Mean sigma: 1.860596
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.002312
# [t-SNE] KL divergence after 300 iterations: 1.848945
# t-SNE done! Time elapsed: 15.24599313735962 seconds

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(
    x=X2[:,0], y=X2[:,1],
    palette=sns.color_palette("hls", 10),
    legend="full",
    alpha=0.3
)


fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(1, 1, 1)
ax.set_xlabel('TSNE-1', fontsize=15)
ax.set_ylabel('TSNE-2', fontsize=15)
ax.scatter(X2[:, 0]
               , X2[:, 1]
               , c='blue'
               , s=50)
ax.grid()
plt.show()
